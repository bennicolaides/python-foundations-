# %% [markdown]
# <a href="https://colab.research.google.com/github/bennicolaides/python-foundations-/blob/main/chapter_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# this program says hello and asks for name and age

print('Hello, world!')

# ask for name
print('What is your name?')
my_name = input('>')                                                # waits for you to press enyter

print('It is good to meet you, ' + my_name)
print('The length of your name is:')
print(len(my_name))                                                 # shows how many letters are in the name

# ask for age
print('What is your age?')
my_age = input('>')

# calculate next year's age
print('You will be ' + str(int(my_age) + 1) + ' in a year.')
# Out:
# Hello, world!
# What is your name?
# >ben
# It is good to meet you, ben
# The length of your name is:
# 3
# What is your age?
# >21
# You will be 22 in a year.

# %%
print('how old are you?')
age = input()

print('You are', age, 'years old')
# Out:
# how old are you?
# 21
# You are 21 years old

# %%
print('how old are you?')


print('You are', input(), 'years old')
# Out:
# how old are you?
# 21
# You are 21 years old

# %%
len('harry potter')
# Out:
# 12

# %%
name = input('what is your name? ')

length = len(name)

print('Your name is', length, 'characters long')
# Out:
# what is your name? legolas
# Your name is 7 characters long

# %%
len('i love hotdogs')
# Out:
# 14

# %%
str(47)
# Out:
# '47'

# %%
str('five')
# Out:
# 'five'

# %%
str(33874)
# Out:
# '33874'

# %%
print('i am ' + str(29) + ' years old')
# Out:
# i am 29 years old

# %%
print('i am 29 years old')
# Out:
# i am 29 years old

# %%
str(0)
# Out:
# '0'

# %%
int(-2.34)
# Out:
# -2

# %%
str(-2.344)
# Out:
# '-2.344'

# %%
int(-9383)
# Out:
# -9383

# %%
-39398
# Out:
# -39398

# %%
int(1.29247)
# Out:
# 1

# %%
int(2.9999)
# Out:
# 2

# %%
float(3.3439)
# Out:
# 3.3439

# %%
float(2000)
# Out:
# 2000.0

# %%
answer = input('>')
answer
# Out:
# >101
# '101'

# %%
answer = int(answer)
answer
# Out:
# 101

# %%
answer * 10 % 34
# Out:
# 24

# %%
int('38')
# Out:
# 38

# %%
int('3948.93')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1840277822.py in <cell line: 0>()
# ----> 1 int('3948.93')
#
# ValueError: invalid literal for int() with base 10: '3948.93'

# %%
float('9437.434')
# Out:
# 9437.434

# %%
int(4.99)
# Out:
# 4

# %%
int(8.3837) + 282
# Out:
# 290

# %%
print('What is your age?')
age = int(input('>'))
print('You will be', age + 1, 'in a year')
# Out:
# What is your age?
# >21
# You will be 22 in a year

# %%
type('ji')
# Out:
# str

# %%
type(3838)
# Out:
# int

# %%
type(9.383)
# Out:
# float

# %%
name = 'zophie'
type(name)
# Out:
# str

# %%
type(len(name))
# Out:
# int

# %%
type(print('hello'))
# Out:
# hello
# NoneType

# %%
print(type('hello'))
# Out:
# <class 'str'>

# %%
type('hello')
# Out:
# str

# %%
round(8.3737)
# Out:
# 8

# %%
round(8.9)
# Out:
# 9

# %%
round('hi')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3949665.py in <cell line: 0>()
# ----> 1 round('hi')
#
# TypeError: type str doesn't define __round__ method

# %%
round(-3.55)
# Out:
# -4

# %%
round(9.33734, 4)
# Out:
# 9.3373

# %%
round(8.2933838, 6)
# Out:
# 8.293384

# %%
round(2.5)
# Out:
# 2

# %%
round(3.5)
# Out:
# 4

# %%
abs(38)
# Out:
# 38

# %%
abs(-303)
# Out:
# 303

# %%
abs(38.4)
# Out:
# 38.4

# %%
abs(-393844848.3939)
# Out:
# 393844848.3939

# %%
100 // 13
# Out:
# 7
