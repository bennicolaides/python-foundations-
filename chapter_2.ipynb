# %% [markdown]
# <a href="https://colab.research.google.com/github/bennicolaides/python-foundations-/blob/main/chapter_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
spam = True = 1

# %%
spam
# Out:
# True

# %%
True
# Out:
# True

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-592217714.py in <cell line: 0>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
False = 2 + 2
# Out:
#   File "/tmp/ipython-input-3086977152.py", line 1
#     False = 2 + 2
#     ^
# SyntaxError: cannot assign to False

# %%
True = 'let us go'
True
# Out:
#   File "/tmp/ipython-input-1076797365.py", line 1
#     True = 'let us go'
#     ^
# SyntaxError: cannot assign to True

# %%
3 == 2 + 1
# Out:
# True

# %%
5 == 7
# Out:
# False

# %%
6 * 8 == 48
# Out:
# True

# %%
8 // 3 == 2.3
# Out:
# False

# %%
5 != 78
# Out:
# True

# %%
8 != 4 * 2
# Out:
# False

# %%
1.999 < 8
# Out:
# True

# %%
34 > 33.9999
# Out:
# True

# %%
34 <= 34.0
# Out:
# True

# %%
45 <= 23
# Out:
# False

# %%
'cat' == 'cat'
# Out:
# True

# %%
'hi' == 'hI'
# Out:
# False

# %%
'dog' != 'cat'
# Out:
# True

# %%
636 == '636'
# Out:
# False

# %%
cow = 45
cow >= 34
# Out:
# True

# %%
my_age = 9 * 8
my_age != 72
# Out:
# False

# %%
cow == my_age - 27
# Out:
# True

# %%
True and True
# Out:
# True

# %%
5 and 6
# Out:
# 6

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
5 or 6
# Out:
# 5

# %%
not True
# Out:
# False

# %%
not not not not not True
# Out:
# False

# %%
not not False
# Out:
# False

# %%
not False
# Out:
# True

# %%
True not False
# Out:
#   File "/tmp/ipython-input-427692260.py", line 1
#     True not False
#              ^
# SyntaxError: invalid syntax

# %%
not -10.8383
# Out:
# False

# %%
not 5
# Out:
# False

# %%
not'me'
# Out:
# False

# %%
(4 < 5) and (9 < 10)
# Out:
# True

# %%
4 < 5 and 9 < 4
# Out:
# False

# %%
1 == 2 or 3 * 3 == 9
# Out:
# True

# %%
cow = 4
2 + 2 == cow and not 2 + 2 == spam + 1 or 2 * 2 == 2 + 1
# Out:
# True

# %%
name = 'ben'
password = 'emilia'
if name == 'ben':
  print('Hello Ben!')
  if password == 'emilia':
    print('Access granted')
  else:
    print('Access denied')
# Out:
# Hello Ben!
# Access denied

# %%
name = 'ben'
password = 'emilia'
if name == 'ben':
  print('Hello Ben!')
  if password == 'emilia':
    print('Access granted')
  else:
    print('Access denied')
else:
  print('Who is this?')
# Out:
# Hello Ben!
# Access granted

# %%
name = 'johnathan'
if len(name) <= 5:
  print('You have a short name')
else:
  print('You have a long name')
# Out:
# You have a long name

# %%
name = 'ben'
age = 11
if name == 'ben' and age >= 12:
  print('Hi Ben')
elif age < 12:
  print('You are not Ben, kiddo!')
# Out:
# You are not Ben, kiddo!

# %%
name = 'john'
age = 4000

if name == 'ben':
  print('Hi, Ben!')
elif age < 12:
  print('You are not Ben, kiddo.')
elif age > 2000:
  print('Unlike you, Ben is not an undead immortal vampire.')
elif age >= 100:
  print('You are not Ben, grannie.')
# Out:
# Unlike you, Ben is not an undead immortal vampire.

# %%
name = 'john'
age = 4000

if name == 'ben':
  print('Hi, Ben!')
elif age < 12:
  print('You are not Ben, kiddo.')
elif age > 100:
  print('You are not Ben, grannie.')
elif age > 2000:
  print('Unlike you, Ben is not an undead immortal vampire.')
# Out:
# You are not Ben, grannie.

# %%
name = 'john'
age = 11
if name == 'ben':
  print('Hi Ben!')
elif age < 12:
  print('You are not Ben kiddo')
else:
  print('You are neither Ben nor a little kid')
# Out:
# You are not Ben kiddo

# %%
today_is_opposite_day = False

if today_is_opposite_day == True:
  say_it_is_opposite_day = True
else:
  say_it_is_opposite_day = False

if today_is_opposite_day == True:
  say_it_is_opposite_day = not say_it_is_opposite_day

if say_it_is_opposite_day == True:
  print('Today is opposite day.')
else:
  print('Today is not opposite day.')
# Out:
# Today is not opposite day.

# %%
print('Enter TB or GB for the advertised unit')
unit = input('>')

if unit == 'TB' or unit == 'tb':
  discrepancy = 10000000000000 / 1099511627776
elif unit == 'GB' or 'gb':
  discrepancy = 1000000000 / 1073741824

print('Enter the advertised capacity:')
advertised_capacity = input('>')
advertised_capacity = float(advertised_capacity)

real_capacity = str(round(advertised_capacity * discrepancy, 2))

print('The actual capacity is ' + real_capacity + unit)
# Out:
# Enter TB or GB for the advertised unit
# >tb
# Enter the advertised capacity:
# >1000000
# The actual capacity is 9094947.02tb

# %%
print('How old are you?')
age = input('>')
age = int(age)

if age < 18:
  print('You are a minor.')
elif age < 65:
  print('You are an adult.')
elif age < 100:
  print('Collect your social security .')
else:
  print('Alright immortal vampire, it is time to pack it up.')
# Out:
# How old are you?
# >40
# You are an adult.

# %%
spam = 0

if spam == 1:
  print('Hello.')
elif spam == 2:
  print('Howdy.')
else:
  print('Greetings!')
# Out:
# Greetings!
